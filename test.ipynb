# %%
import os, json, pickle

# %%
with open("./spk_meta/spk_meta_trn.pk", "rb") as f:
    data = pickle.load(f)

# %%
data
# Out:
# {'LA_0079': {'bonafide': ['LA_T_1138215',
#    'LA_T_1271820',
#    'LA_T_1272637',
#    'LA_T_1276960',
#    'LA_T_1341447',
#    'LA_T_1363611',
#    'LA_T_1596451',
#    'LA_T_1608170',
#    'LA_T_1684951',
#    'LA_T_1699801',
#    'LA_T_1703395',
#    'LA_T_1736342',
#    'LA_T_1779188',
#    'LA_T_1786825',
#    'LA_T_1787246',
#    'LA_T_1905558',
#    'LA_T_2205687',
#    'LA_T_2220901',
#    'LA_T_2361751',
#    'LA_T_2373806',
#    'LA_T_2417641',
#    'LA_T_2520083',
#    'LA_T_2562689',
#    'LA_T_2564579',
#    'LA_T_2732709',
#    'LA_T_2759900',
#    'LA_T_2838981',
#    'LA_T_2873890',
#    'LA_T_2938316',
#    'LA_T_3131990',
#    'LA_T_3141223',
#    'LA_T_3167734',
#    'LA_T_3187715',
#    'LA_T_3215578',
#    'LA_T_3247389',
#    'LA_T_3346004',
#    'LA_T_3441957',
#    'LA_T_3561136',
#    'LA_T_3576775',
#    'LA_T_3580508',
#    'LA_T_3635733',
#    'LA_T_3636245',
#    'LA_T_3810183',
#    'LA_T_3849267',
#    'LA_T_3995089',
#    'LA_T_3999087',
# ...
